# %%
import pandas as pd

df = pd.read_csv("student_data.csv")
df.head()
# Out:
#                name  gender  study_hours  marks    education
# 0        Ed Braxton    Male            2     55  High School
# 1        Karl Braun    Male            4     70     Bachelor
# 2       John Murray    Male            1     40  High School
# 3  Stephanie Phelps  Female            5     85       Master
# 4       Ted Trevino    Male            3     65     Bachelor

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         10 non-null     str
#  1   gender       10 non-null     str
#  2   study_hours  10 non-null     int64
#  3   marks        10 non-null     int64
#  4   education    10 non-null     str
# dtypes: int64(2), str(3)
# memory usage: 532.0 bytes

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         10 non-null     str
#  1   gender       10 non-null     str
#  2   study_hours  10 non-null     int64
#  3   marks        10 non-null     int64
#  4   education    10 non-null     str
# dtypes: int64(2), str(3)
# memory usage: 532.0 bytes

# %%
df["marks"].mean()
# Out:
# np.float64(67.8)

# %%
df.groupby("gender")["marks"].mean()
# Out:
# gender
# Female    78.250000
# Male      60.833333
# Name: marks, dtype: float64

# %%
df.groupby("study_hours")["marks"].mean()
# Out:
# study_hours
# 1    40.0
# 2    52.5
# 3    62.5
# 4    72.5
# 5    86.5
# 6    90.0
# Name: marks, dtype: float64

# %%
df.groupby("education")["marks"].mean()
# Out:
# education
# Bachelor       67.500000
# High School    48.333333
# Master         87.666667
# Name: marks, dtype: float64

# %%
df.to_csv("student_cleaned.csv", index=False)
